# %%
from mem_sim import *

# %%
mem_simulator = MemorySimulator(page_size=4, num_tlb_entries=2, num_frames=4, rep_policy='LRU', debug=True)

# %%
mem_simulator.access_memory(20)
# Out:
# Acessando endereço virtual: 20
# TLB Miss para a página 5
# Page Fault para a página 5
# Acessando endereço virtual: 20
# TLB Hit para a página 5
